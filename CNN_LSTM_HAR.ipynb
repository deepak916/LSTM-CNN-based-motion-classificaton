# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
  # !cp -r '/content/drive/My Drive/mycode_dataset' '/subject101.dat'

# %% [markdown]
# #Importing library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import scipy.stats as stats
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix,accuracy_score,log_loss

# %% [markdown]
# #Load data

# %%
def load_activity_map():
    map = {}
    map[0] = 'transient'
    map[1] = 'lying'
    map[2] = 'sitting'
    map[3] = 'standing'
    map[4] = 'walking'
    map[5] = 'running'
    map[6] = 'cycling'
    map[7] = 'Nordic_walking'
    map[9] = 'watching_TV'
    map[10] = 'computer_work'
    map[11] = 'car driving'
    map[12] = 'ascending_stairs'
    map[13] = 'descending_stairs'
    map[16] = 'vacuum_cleaning'
    map[17] = 'ironing'
    map[18] = 'folding_laundry'
    map[19] = 'house_cleaning'
    map[20] = 'playing_soccer'
    map[24] = 'rope_jumping'
    return map

# %%
def generate_three_IMU(name):
    x = name +'_x'
    y = name +'_y'
    z = name +'_z'
    return [x,y,z]

def generate_four_IMU(name):
    x = name +'_x'
    y = name +'_y'
    z = name +'_z'
    w = name +'_w'
    return [x,y,z,w]

def generate_cols_IMU(name):
    # temp
    temp = name+'_temperature'
    output = [temp]
    # acceleration 16
    acceleration16 = name+'_3D_acceleration_16'
    acceleration16 = generate_three_IMU(acceleration16)
    output.extend(acceleration16)
    # acceleration 6
    acceleration6 = name+'_3D_acceleration_6'
    acceleration6 = generate_three_IMU(acceleration6)
    output.extend(acceleration6)
    # gyroscope
    gyroscope = name+'_3D_gyroscope'
    gyroscope = generate_three_IMU(gyroscope)
    output.extend(gyroscope)
    # magnometer
    magnometer = name+'_3D_magnetometer'
    magnometer = generate_three_IMU(magnometer)
    output.extend(magnometer)
    # oreintation
    oreintation = name+'_4D_orientation'
    oreintation = generate_four_IMU(oreintation)
    output.extend(oreintation)
    return output

def load_IMU():
    output = ['time_stamp','activity_id', 'heart_rate']
    hand = 'hand'
    hand = generate_cols_IMU(hand)
    output.extend(hand)
    chest = 'chest'
    chest = generate_cols_IMU(chest)
    output.extend(chest)
    ankle = 'ankle'
    ankle = generate_cols_IMU(ankle)
    output.extend(ankle)
    return output
    
def load_subjects(root='/content/drive/My Drive/mycode_dataset' '/subject'):
    output = pd.DataFrame()
    cols = load_IMU()
    
    for i in range(101,109):
        path = root + str(i) +'.dat'
        subject = pd.read_table(path, header=None, sep='\s+')
        subject.columns = cols 
        subject['id'] = i
        output = output.append(subject, ignore_index=True)
    output.reset_index(drop=True, inplace=True)
    return output

data = load_subjects()

# %%
data
# Out:
#          time_stamp  activity_id  ...  ankle_4D_orientation_w   id
# 0              8.38            0  ...                0.000000  101
# 1              8.39            0  ...                0.000000  101
# 2              8.40            0  ...                0.000000  101
# 3              8.41            0  ...                0.000000  101
# 4              8.42            0  ...                0.000000  101
# ...             ...          ...  ...                     ...  ...
# 2864051     4086.15            0  ...               -0.483116  108
# 2864052     4086.16            0  ...               -0.483148  108
# 2864053     4086.17            0  ...               -0.483167  108
# 2864054     4086.18            0  ...               -0.483206  108
# 2864055     4086.19            0  ...               -0.483207  108
#
# [2864056 rows x 55 columns]

# %% [markdown]
# # Data pre processing

# %%
def fix_data(data):
    select = [4,5,7,12,13,24]
    #data = data.drop(data[data['activity_id']==0].index)
    data=data[data['activity_id'].isin(select)]
    data=data[['time_stamp','activity_id','ankle_3D_acceleration_6_x','ankle_3D_acceleration_6_y','ankle_3D_acceleration_6_z','ankle_3D_gyroscope_x','ankle_3D_gyroscope_y','ankle_3D_gyroscope_z','id']]
    data = data.interpolate()
    # fill all the NaN values in a coulmn with the mean values of the column
    for colName in data.columns:
        data[colName] = data[colName].fillna(data[colName].mean())
    activity_mean = data.groupby(['activity_id']).mean().reset_index()
    return data

data = fix_data(data)

# %%
data
# Out:
#          time_stamp  activity_id  ...  ankle_3D_gyroscope_z   id
# 154281      1551.19           12  ...             -0.009147  101
# 154282      1551.20           12  ...             -0.006737  101
# 154283      1551.21           12  ...              0.008858  101
# 154284      1551.22           12  ...              0.004017  101
# 154285      1551.23           12  ...              0.014554  101
# ...             ...          ...  ...                   ...  ...
# 2844273     3888.37           24  ...             -0.102102  108
# 2844274     3888.38           24  ...             -0.078137  108
# 2844275     3888.39           24  ...             -0.096625  108
# 2844276     3888.40           24  ...             -0.067416  108
# 2844277     3888.41           24  ...             -0.064166  108
#
# [790196 rows x 9 columns]

# %% [markdown]
# #Data Explore

# %%
data['activity_id'].value_counts()
# Out:
# 4     238761
# 7     188107
# 12    117216
# 13    104944
# 5      98199
# 24     42969
# Name: activity_id, dtype: int64

# %%
data.describe()
# Out:
#           time_stamp    activity_id  ...  ankle_3D_gyroscope_z             id
# count  790196.000000  790196.000000  ...         790196.000000  790196.000000
# mean     2583.508905       8.307949  ...              0.009858     104.532245
# std       648.653906       5.070546  ...              3.072677       2.348308
# min      1461.210000       4.000000  ...            -14.019600     101.000000
# 25%      2015.820000       4.000000  ...             -2.025410     102.000000
# 50%      2487.210000       7.000000  ...             -0.435700     105.000000
# 75%      3123.840000      12.000000  ...              1.521303     107.000000
# max      4245.680000      24.000000  ...             16.528800     108.000000
#
# [8 rows x 9 columns]

# %%
print('Size of the data: ', data.size)
print('Shape of the data: ', data.shape)
print('Number of columns in the data: ', len(data.columns))
#result_id = data.groupby(['id']).mean().reset_index()
#print('Number of unique ids in the data: ', len(result_id))
result_act = data.groupby(['activity_id']).mean().reset_index()
print('Numbe of unique activities in the data: ',len(result_act))
# Out:
# Size of the data:  7111764
# Shape of the data:  (790196, 9)
# Number of columns in the data:  9
# Numbe of unique activities in the data:  6

# %%
def pd_fast_plot(pd,column_a,column_b,title, figsize=(10,6)):
    plt.rcParams.update({'font.size': 16})
    size = range(len(pd))
    f, ax = plt.subplots(figsize=figsize) 
    plt.bar(size, pd[column_a], color=plt.cm.Paired(size))
    a = ax.set_xticklabels(pd[column_b])
    b = ax.legend(fontsize = 20)
    c = ax.set_xticks(np.arange(len(pd)))
    d = ax.set_title(title)
    plt.show()

# %%
samples = data.groupby(['id']).count().reset_index()
samples_to_subject = pd.DataFrame()
samples_to_subject['id'] = samples['id']
samples_to_subject['samples'] = samples['time_stamp']
samples_to_subject = samples_to_subject.sort_values(by=['samples'])
pd_fast_plot(samples_to_subject,'samples','id','Number Of Samepls By Users')
# Out:
# No handles with labels found to put in legend.

# %%
map_ac = load_activity_map()
samples = data.groupby(['activity_id']).count().reset_index()
samples_to_subject = pd.DataFrame()
samples_to_subject['activity'] = [map_ac[x] for x in samples['activity_id']]
samples_to_subject['samples'] = samples['time_stamp']
samples_to_subject = samples_to_subject.sort_values(by=['samples'])
pd_fast_plot(samples_to_subject,'samples','activity','Number Of Samepls By Activity',figsize=(40,7))
# Out:
# No handles with labels found to put in legend.

# %%
data['ankle_3D_acceleration_6_x'] = data['ankle_3D_acceleration_6_x'].astype('float')
data['ankle_3D_acceleration_6_y'] = data['ankle_3D_acceleration_6_y'].astype('float')
data['ankle_3D_acceleration_6_z'] = data['ankle_3D_acceleration_6_z'].astype('float')
data['ankle_3D_gyroscope_x'] = data['ankle_3D_gyroscope_x'].astype('float')
data['ankle_3D_gyroscope_y'] = data['ankle_3D_gyroscope_y'].astype('float')
data['ankle_3D_gyroscope_z'] = data['ankle_3D_gyroscope_z'].astype('float')

# %%
features = data[['ankle_3D_acceleration_6_x','ankle_3D_acceleration_6_y','ankle_3D_acceleration_6_z','ankle_3D_gyroscope_x','ankle_3D_gyroscope_y','ankle_3D_gyroscope_z']]
label = data['activity_id']

# %%
data['activity_id'].value_counts()
# Out:
# 4     238761
# 7     188107
# 12    117216
# 13    104944
# 5      98199
# 24     42969
# Name: activity_id, dtype: int64

# %% [markdown]
# #Balancing dataset

# %%
Walking = data[data['activity_id']==4].head(42969).copy()
Jogging = data[data['activity_id']==5].head(42969).copy()
Upstairs = data[data['activity_id']==7].head(42969).copy()
Downstairs = data[data['activity_id']==12].head(42969).copy()
Sitting = data[data['activity_id']==13].head(42969).copy()
Standing = data[data['activity_id']==24].copy()

balanced_data = pd.DataFrame()
balanced_data = balanced_data.append([Walking, Jogging, Upstairs, Downstairs, Sitting, Standing])
balanced_data.shape
# Out:
# (257814, 9)

# %%
balanced_data['activity_id'].value_counts()
# Out:
# 24    42969
# 13    42969
# 12    42969
# 7     42969
# 5     42969
# 4     42969
# Name: activity_id, dtype: int64

# %%
balanced_data.head()
# Out:
#         time_stamp  activity_id  ...  ankle_3D_gyroscope_z   id
# 223759     2245.97            4  ...              0.010491  101
# 223760     2245.98            4  ...             -0.013735  101
# 223761     2245.99            4  ...             -0.009751  101
# 223762     2246.00            4  ...              0.009661  101
# 223763     2246.01            4  ...             -0.014538  101
#
# [5 rows x 9 columns]

# %% [markdown]
# #Standardization of data

# %%
label = LabelEncoder()
balanced_data['label'] = label.fit_transform(balanced_data['activity_id'])
balanced_data.head()
# Out:
#         time_stamp  activity_id  ...   id  label
# 223759     2245.97            4  ...  101      0
# 223760     2245.98            4  ...  101      0
# 223761     2245.99            4  ...  101      0
# 223762     2246.00            4  ...  101      0
# 223763     2246.01            4  ...  101      0
#
# [5 rows x 10 columns]

# %%
features = balanced_data[['ankle_3D_acceleration_6_x','ankle_3D_acceleration_6_y','ankle_3D_acceleration_6_z','ankle_3D_gyroscope_x','ankle_3D_gyroscope_y','ankle_3D_gyroscope_z']]
label = balanced_data['label']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(features)

scaled_X = pd.DataFrame(data = X, columns = ['ankle_3D_acceleration_6_x','ankle_3D_acceleration_6_y','ankle_3D_acceleration_6_z','ankle_3D_gyroscope_x','ankle_3D_gyroscope_y','ankle_3D_gyroscope_z'])
scaled_X['label'] = label.values

scaled_X.head()
# Out:
#    ankle_3D_acceleration_6_x  ...  label
# 0                  -0.204379  ...      0
# 1                  -0.200644  ...      0
# 2                  -0.198825  ...      0
# 3                  -0.204342  ...      0
# 4                  -0.204332  ...      0
#
# [5 rows x 7 columns]

# %% [markdown]
# #Frame Preparation

# %%
Fs = 20
frame_size = Fs*4 # 80
hop_size = Fs*2 # 40

# %%
def get_frames(df, frame_size, hop_size):

    N_FEATURES = 6

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, hop_size):
        ax = df['ankle_3D_acceleration_6_x'].values[i: i + frame_size]
        ay = df['ankle_3D_acceleration_6_y'].values[i: i + frame_size]
        az = df['ankle_3D_acceleration_6_z'].values[i: i + frame_size]
        gx = df['ankle_3D_gyroscope_x'].values[i: i + frame_size]
        gy = df['ankle_3D_gyroscope_y'].values[i: i + frame_size]
        gz = df['ankle_3D_gyroscope_z'].values[i: i + frame_size]
        
        # Retrieve the most often used label in this segment
        label = stats.mode(df['label'][i: i + frame_size])[0][0]
        frames.append([ax, ay, az, gx, gy, gz])
        labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

X, y = get_frames(scaled_X, frame_size, hop_size)

X.shape, y.shape
# Out:
# ((6444, 80, 6), (6444,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0, stratify = y)

# %%
X_train.shape, X_test.shape
# Out:
# ((5155, 80, 6), (1289, 80, 6))

# %%
X_train[0].shape, X_test[0].shape
# Out:
# ((80, 6), (80, 6))

# %%
X_train = X_train.reshape(5155, 80, 6, 1)
X_test = X_test.reshape(1289, 80, 6, 1)

# %% [markdown]
# #CNN-LSTM Model

# %%
# define model
model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(X_train[0].shape)))
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(Dropout(0.5)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(100))
model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(Dense(6, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate = 0.001), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(X_train, y_train, epochs = 200, validation_data= (X_test, y_test), verbose=1)
# Out:
# Epoch 1/200
# 162/162 [==============================] - 5s 18ms/step - loss: 0.1691 - accuracy: 0.9294 - val_loss: 0.3577 - val_accuracy: 0.8844
# Epoch 2/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.2004 - accuracy: 0.9216 - val_loss: 0.3900 - val_accuracy: 0.8844
# Epoch 3/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1754 - accuracy: 0.9354 - val_loss: 0.3663 - val_accuracy: 0.8937
# Epoch 4/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1480 - accuracy: 0.9442 - val_loss: 0.3909 - val_accuracy: 0.8774
# Epoch 5/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1592 - accuracy: 0.9414 - val_loss: 0.3392 - val_accuracy: 0.8991
# Epoch 6/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1601 - accuracy: 0.9350 - val_loss: 0.3646 - val_accuracy: 0.8937
# Epoch 7/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1795 - accuracy: 0.9321 - val_loss: 0.3301 - val_accuracy: 0.8922
# Epoch 8/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.2564 - accuracy: 0.9088 - val_loss: 0.4026 - val_accuracy: 0.8720
# Epoch 9/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1855 - accuracy: 0.9277 - val_loss: 0.3605 - val_accuracy: 0.8883
# Epoch 10/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1606 - accuracy: 0.9348 - val_loss: 0.3402 - val_accuracy: 0.8929
# Epoch 11/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.2517 - accuracy: 0.9124 - val_loss: 0.4130 - val_accuracy: 0.8813
# Epoch 12/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1688 - accuracy: 0.9335 - val_loss: 0.3642 - val_accuracy: 0.8836
# Epoch 13/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1432 - accuracy: 0.9438 - val_loss: 0.3725 - val_accuracy: 0.8860
# Epoch 14/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1429 - accuracy: 0.9432 - val_loss: 0.3775 - val_accuracy: 0.8829
# Epoch 15/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1677 - accuracy: 0.9363 - val_loss: 0.3944 - val_accuracy: 0.8829
# Epoch 16/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1533 - accuracy: 0.9391 - val_loss: 0.4203 - val_accuracy: 0.8751
# Epoch 17/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1387 - accuracy: 0.9487 - val_loss: 0.3394 - val_accuracy: 0.8999
# Epoch 18/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1409 - accuracy: 0.9402 - val_loss: 0.4232 - val_accuracy: 0.8821
# Epoch 19/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1843 - accuracy: 0.9366 - val_loss: 0.3887 - val_accuracy: 0.8836
# Epoch 20/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1531 - accuracy: 0.9382 - val_loss: 0.3354 - val_accuracy: 0.8984
# Epoch 21/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1585 - accuracy: 0.9412 - val_loss: 0.3519 - val_accuracy: 0.8984
# Epoch 22/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1558 - accuracy: 0.9409 - val_loss: 0.4186 - val_accuracy: 0.8766
# Epoch 23/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1947 - accuracy: 0.9294 - val_loss: 0.4035 - val_accuracy: 0.8813
# Epoch 24/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1467 - accuracy: 0.9436 - val_loss: 0.3494 - val_accuracy: 0.8937
# Epoch 25/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1437 - accuracy: 0.9437 - val_loss: 0.3675 - val_accuracy: 0.8906
# Epoch 26/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1423 - accuracy: 0.9473 - val_loss: 0.3587 - val_accuracy: 0.8976
# Epoch 27/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1426 - accuracy: 0.9415 - val_loss: 0.4499 - val_accuracy: 0.8759
# Epoch 28/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1620 - accuracy: 0.9409 - val_loss: 0.4214 - val_accuracy: 0.8790
# Epoch 29/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1686 - accuracy: 0.9334 - val_loss: 0.4077 - val_accuracy: 0.8821
# Epoch 30/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1360 - accuracy: 0.9473 - val_loss: 0.3548 - val_accuracy: 0.9046
# Epoch 31/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1442 - accuracy: 0.9467 - val_loss: 0.3748 - val_accuracy: 0.8929
# Epoch 32/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1517 - accuracy: 0.9392 - val_loss: 0.3485 - val_accuracy: 0.9007
# Epoch 33/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1324 - accuracy: 0.9507 - val_loss: 0.3467 - val_accuracy: 0.8984
# Epoch 34/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1362 - accuracy: 0.9503 - val_loss: 0.3336 - val_accuracy: 0.9061
# Epoch 35/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1294 - accuracy: 0.9498 - val_loss: 0.4197 - val_accuracy: 0.8937
# Epoch 36/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1134 - accuracy: 0.9558 - val_loss: 0.4653 - val_accuracy: 0.8844
# Epoch 37/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1329 - accuracy: 0.9431 - val_loss: 0.4023 - val_accuracy: 0.8867
# Epoch 38/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1239 - accuracy: 0.9525 - val_loss: 0.4532 - val_accuracy: 0.8852
# Epoch 39/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1763 - accuracy: 0.9368 - val_loss: 0.4243 - val_accuracy: 0.8860
# Epoch 40/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1485 - accuracy: 0.9451 - val_loss: 0.4065 - val_accuracy: 0.8898
# Epoch 41/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1321 - accuracy: 0.9489 - val_loss: 0.4257 - val_accuracy: 0.8914
# Epoch 42/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1294 - accuracy: 0.9491 - val_loss: 0.3962 - val_accuracy: 0.8883
# Epoch 43/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1257 - accuracy: 0.9508 - val_loss: 0.4420 - val_accuracy: 0.8790
# Epoch 44/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1266 - accuracy: 0.9467 - val_loss: 0.3704 - val_accuracy: 0.9015
# Epoch 45/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1417 - accuracy: 0.9467 - val_loss: 0.3674 - val_accuracy: 0.8984
# Epoch 46/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1254 - accuracy: 0.9496 - val_loss: 0.3423 - val_accuracy: 0.9054
# Epoch 47/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1207 - accuracy: 0.9557 - val_loss: 0.3514 - val_accuracy: 0.9030
# Epoch 48/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1206 - accuracy: 0.9507 - val_loss: 0.3774 - val_accuracy: 0.8898
# Epoch 49/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1207 - accuracy: 0.9522 - val_loss: 0.3533 - val_accuracy: 0.9038
# Epoch 50/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1076 - accuracy: 0.9596 - val_loss: 0.4037 - val_accuracy: 0.8906
# Epoch 51/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1305 - accuracy: 0.9513 - val_loss: 0.4111 - val_accuracy: 0.8937
# Epoch 52/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1477 - accuracy: 0.9433 - val_loss: 0.3897 - val_accuracy: 0.8906
# Epoch 53/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1442 - accuracy: 0.9444 - val_loss: 0.3154 - val_accuracy: 0.9046
# Epoch 54/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1315 - accuracy: 0.9468 - val_loss: 0.4717 - val_accuracy: 0.8759
# Epoch 55/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1268 - accuracy: 0.9529 - val_loss: 0.4461 - val_accuracy: 0.8805
# Epoch 56/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1358 - accuracy: 0.9470 - val_loss: 0.4578 - val_accuracy: 0.8891
# Epoch 57/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1380 - accuracy: 0.9486 - val_loss: 0.4083 - val_accuracy: 0.8883
# Epoch 58/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1310 - accuracy: 0.9527 - val_loss: 0.4568 - val_accuracy: 0.8751
# Epoch 59/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1461 - accuracy: 0.9445 - val_loss: 0.4797 - val_accuracy: 0.8860
# Epoch 60/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1403 - accuracy: 0.9474 - val_loss: 0.4050 - val_accuracy: 0.8860
# Epoch 61/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1238 - accuracy: 0.9493 - val_loss: 0.3827 - val_accuracy: 0.8976
# Epoch 62/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1140 - accuracy: 0.9525 - val_loss: 0.3702 - val_accuracy: 0.8867
# Epoch 63/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1415 - accuracy: 0.9479 - val_loss: 0.3766 - val_accuracy: 0.8898
# Epoch 64/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1422 - accuracy: 0.9491 - val_loss: 0.3556 - val_accuracy: 0.8999
# Epoch 65/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1199 - accuracy: 0.9526 - val_loss: 0.3794 - val_accuracy: 0.8953
# Epoch 66/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1359 - accuracy: 0.9485 - val_loss: 0.4457 - val_accuracy: 0.8766
# Epoch 67/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1167 - accuracy: 0.9555 - val_loss: 0.3324 - val_accuracy: 0.8991
# Epoch 68/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1235 - accuracy: 0.9490 - val_loss: 0.3160 - val_accuracy: 0.8999
# Epoch 69/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1156 - accuracy: 0.9518 - val_loss: 0.3601 - val_accuracy: 0.8984
# Epoch 70/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1270 - accuracy: 0.9512 - val_loss: 0.3588 - val_accuracy: 0.9046
# Epoch 71/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1057 - accuracy: 0.9597 - val_loss: 0.3850 - val_accuracy: 0.9022
# Epoch 72/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0967 - accuracy: 0.9593 - val_loss: 0.3717 - val_accuracy: 0.9022
# Epoch 73/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1014 - accuracy: 0.9650 - val_loss: 0.3684 - val_accuracy: 0.9030
# Epoch 74/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1324 - accuracy: 0.9485 - val_loss: 0.3408 - val_accuracy: 0.8945
# Epoch 75/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1155 - accuracy: 0.9558 - val_loss: 0.4053 - val_accuracy: 0.8960
# Epoch 76/200
# 162/162 [==============================] - 2s 10ms/step - loss: 0.1068 - accuracy: 0.9605 - val_loss: 0.3997 - val_accuracy: 0.8945
# Epoch 77/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0998 - accuracy: 0.9590 - val_loss: 0.3673 - val_accuracy: 0.9007
# Epoch 78/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1153 - accuracy: 0.9519 - val_loss: 0.4056 - val_accuracy: 0.8945
# Epoch 79/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1411 - accuracy: 0.9484 - val_loss: 0.3558 - val_accuracy: 0.8999
# Epoch 80/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1231 - accuracy: 0.9481 - val_loss: 0.3969 - val_accuracy: 0.8976
# Epoch 81/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1304 - accuracy: 0.9509 - val_loss: 0.3791 - val_accuracy: 0.8968
# Epoch 82/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1242 - accuracy: 0.9529 - val_loss: 0.4454 - val_accuracy: 0.8821
# Epoch 83/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1174 - accuracy: 0.9547 - val_loss: 0.3290 - val_accuracy: 0.9030
# Epoch 84/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.1147 - accuracy: 0.9574 - val_loss: 0.3823 - val_accuracy: 0.8782
# Epoch 85/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1226 - accuracy: 0.9538 - val_loss: 0.3608 - val_accuracy: 0.9038
# Epoch 86/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0964 - accuracy: 0.9612 - val_loss: 0.4667 - val_accuracy: 0.8813
# Epoch 87/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1063 - accuracy: 0.9624 - val_loss: 0.3762 - val_accuracy: 0.9030
# Epoch 88/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1095 - accuracy: 0.9597 - val_loss: 0.4065 - val_accuracy: 0.8968
# Epoch 89/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1084 - accuracy: 0.9561 - val_loss: 0.4192 - val_accuracy: 0.8914
# Epoch 90/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1926 - accuracy: 0.9336 - val_loss: 0.3407 - val_accuracy: 0.9030
# Epoch 91/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1157 - accuracy: 0.9552 - val_loss: 0.3903 - val_accuracy: 0.8914
# Epoch 92/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0980 - accuracy: 0.9586 - val_loss: 0.3881 - val_accuracy: 0.8991
# Epoch 93/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1008 - accuracy: 0.9571 - val_loss: 0.3314 - val_accuracy: 0.9030
# Epoch 94/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0901 - accuracy: 0.9655 - val_loss: 0.3735 - val_accuracy: 0.9100
# Epoch 95/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0981 - accuracy: 0.9615 - val_loss: 0.4106 - val_accuracy: 0.8968
# Epoch 96/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0975 - accuracy: 0.9645 - val_loss: 0.3277 - val_accuracy: 0.9116
# Epoch 97/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1342 - accuracy: 0.9528 - val_loss: 0.3218 - val_accuracy: 0.9123
# Epoch 98/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1484 - accuracy: 0.9489 - val_loss: 0.4226 - val_accuracy: 0.8836
# Epoch 99/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1238 - accuracy: 0.9546 - val_loss: 0.4387 - val_accuracy: 0.9015
# Epoch 100/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1304 - accuracy: 0.9509 - val_loss: 0.4490 - val_accuracy: 0.8805
# Epoch 101/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1141 - accuracy: 0.9582 - val_loss: 0.3652 - val_accuracy: 0.9015
# Epoch 102/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0972 - accuracy: 0.9613 - val_loss: 0.3708 - val_accuracy: 0.9046
# Epoch 103/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0974 - accuracy: 0.9610 - val_loss: 0.4286 - val_accuracy: 0.8883
# Epoch 104/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0972 - accuracy: 0.9638 - val_loss: 0.4010 - val_accuracy: 0.9015
# Epoch 105/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0899 - accuracy: 0.9684 - val_loss: 0.3953 - val_accuracy: 0.8953
# Epoch 106/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0950 - accuracy: 0.9626 - val_loss: 0.3965 - val_accuracy: 0.9015
# Epoch 107/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1074 - accuracy: 0.9615 - val_loss: 0.3565 - val_accuracy: 0.9030
# Epoch 108/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1340 - accuracy: 0.9486 - val_loss: 0.3755 - val_accuracy: 0.8914
# Epoch 109/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1014 - accuracy: 0.9589 - val_loss: 0.3816 - val_accuracy: 0.8991
# Epoch 110/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0944 - accuracy: 0.9608 - val_loss: 0.3618 - val_accuracy: 0.9108
# Epoch 111/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0914 - accuracy: 0.9629 - val_loss: 0.4208 - val_accuracy: 0.8976
# Epoch 112/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1017 - accuracy: 0.9646 - val_loss: 0.3334 - val_accuracy: 0.9116
# Epoch 113/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1012 - accuracy: 0.9610 - val_loss: 0.3297 - val_accuracy: 0.9077
# Epoch 114/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0986 - accuracy: 0.9613 - val_loss: 0.3807 - val_accuracy: 0.9038
# Epoch 115/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0993 - accuracy: 0.9617 - val_loss: 0.3673 - val_accuracy: 0.9100
# Epoch 116/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0932 - accuracy: 0.9635 - val_loss: 0.3930 - val_accuracy: 0.9030
# Epoch 117/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1256 - accuracy: 0.9539 - val_loss: 0.3855 - val_accuracy: 0.9007
# Epoch 118/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1264 - accuracy: 0.9536 - val_loss: 0.3840 - val_accuracy: 0.9108
# Epoch 119/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1053 - accuracy: 0.9577 - val_loss: 0.4033 - val_accuracy: 0.8929
# Epoch 120/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1009 - accuracy: 0.9584 - val_loss: 0.4044 - val_accuracy: 0.9007
# Epoch 121/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0939 - accuracy: 0.9604 - val_loss: 0.3489 - val_accuracy: 0.9038
# Epoch 122/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1103 - accuracy: 0.9578 - val_loss: 0.3991 - val_accuracy: 0.8984
# Epoch 123/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0989 - accuracy: 0.9605 - val_loss: 0.3869 - val_accuracy: 0.9077
# Epoch 124/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1045 - accuracy: 0.9611 - val_loss: 0.3475 - val_accuracy: 0.9054
# Epoch 125/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0937 - accuracy: 0.9628 - val_loss: 0.3971 - val_accuracy: 0.9038
# Epoch 126/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1019 - accuracy: 0.9624 - val_loss: 0.3690 - val_accuracy: 0.8991
# Epoch 127/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0984 - accuracy: 0.9634 - val_loss: 0.4321 - val_accuracy: 0.8898
# Epoch 128/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1122 - accuracy: 0.9602 - val_loss: 0.4322 - val_accuracy: 0.8867
# Epoch 129/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0964 - accuracy: 0.9623 - val_loss: 0.4077 - val_accuracy: 0.8984
# Epoch 130/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0721 - accuracy: 0.9687 - val_loss: 0.3850 - val_accuracy: 0.9077
# Epoch 131/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0981 - accuracy: 0.9633 - val_loss: 0.4162 - val_accuracy: 0.9030
# Epoch 132/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0778 - accuracy: 0.9681 - val_loss: 0.3927 - val_accuracy: 0.8999
# Epoch 133/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0841 - accuracy: 0.9682 - val_loss: 0.4012 - val_accuracy: 0.9030
# Epoch 134/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0783 - accuracy: 0.9703 - val_loss: 0.4106 - val_accuracy: 0.9108
# Epoch 135/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0813 - accuracy: 0.9683 - val_loss: 0.4400 - val_accuracy: 0.8968
# Epoch 136/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1063 - accuracy: 0.9630 - val_loss: 0.4380 - val_accuracy: 0.8914
# Epoch 137/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0821 - accuracy: 0.9697 - val_loss: 0.4288 - val_accuracy: 0.9015
# Epoch 138/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0935 - accuracy: 0.9643 - val_loss: 0.4451 - val_accuracy: 0.8922
# Epoch 139/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0975 - accuracy: 0.9650 - val_loss: 0.4150 - val_accuracy: 0.8929
# Epoch 140/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0888 - accuracy: 0.9669 - val_loss: 0.3874 - val_accuracy: 0.8968
# Epoch 141/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.1173 - accuracy: 0.9574 - val_loss: 0.3927 - val_accuracy: 0.9069
# Epoch 142/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0994 - accuracy: 0.9587 - val_loss: 0.4399 - val_accuracy: 0.8929
# Epoch 143/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0862 - accuracy: 0.9635 - val_loss: 0.3819 - val_accuracy: 0.9077
# Epoch 144/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0797 - accuracy: 0.9694 - val_loss: 0.4261 - val_accuracy: 0.8937
# Epoch 145/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0872 - accuracy: 0.9670 - val_loss: 0.5234 - val_accuracy: 0.8782
# Epoch 146/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1138 - accuracy: 0.9603 - val_loss: 0.4543 - val_accuracy: 0.8891
# Epoch 147/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0951 - accuracy: 0.9629 - val_loss: 0.4370 - val_accuracy: 0.8999
# Epoch 148/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0821 - accuracy: 0.9694 - val_loss: 0.4618 - val_accuracy: 0.8922
# Epoch 149/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0795 - accuracy: 0.9662 - val_loss: 0.4044 - val_accuracy: 0.8999
# Epoch 150/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1047 - accuracy: 0.9595 - val_loss: 0.4051 - val_accuracy: 0.9100
# Epoch 151/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1045 - accuracy: 0.9611 - val_loss: 0.4541 - val_accuracy: 0.8898
# Epoch 152/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1087 - accuracy: 0.9624 - val_loss: 0.4100 - val_accuracy: 0.9061
# Epoch 153/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0890 - accuracy: 0.9629 - val_loss: 0.3484 - val_accuracy: 0.9077
# Epoch 154/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0937 - accuracy: 0.9636 - val_loss: 0.3655 - val_accuracy: 0.9139
# Epoch 155/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0878 - accuracy: 0.9618 - val_loss: 0.3848 - val_accuracy: 0.9061
# Epoch 156/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0858 - accuracy: 0.9670 - val_loss: 0.4536 - val_accuracy: 0.9054
# Epoch 157/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0793 - accuracy: 0.9686 - val_loss: 0.4410 - val_accuracy: 0.9015
# Epoch 158/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1019 - accuracy: 0.9594 - val_loss: 0.4228 - val_accuracy: 0.8991
# Epoch 159/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0841 - accuracy: 0.9644 - val_loss: 0.4399 - val_accuracy: 0.8960
# Epoch 160/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0929 - accuracy: 0.9616 - val_loss: 0.3884 - val_accuracy: 0.9123
# Epoch 161/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0959 - accuracy: 0.9629 - val_loss: 0.4416 - val_accuracy: 0.9015
# Epoch 162/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0887 - accuracy: 0.9678 - val_loss: 0.4417 - val_accuracy: 0.9054
# Epoch 163/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0710 - accuracy: 0.9705 - val_loss: 0.4736 - val_accuracy: 0.8999
# Epoch 164/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1069 - accuracy: 0.9623 - val_loss: 0.4398 - val_accuracy: 0.8991
# Epoch 165/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0781 - accuracy: 0.9681 - val_loss: 0.4453 - val_accuracy: 0.9054
# Epoch 166/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0848 - accuracy: 0.9660 - val_loss: 0.4205 - val_accuracy: 0.8984
# Epoch 167/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0756 - accuracy: 0.9725 - val_loss: 0.4426 - val_accuracy: 0.9061
# Epoch 168/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1086 - accuracy: 0.9617 - val_loss: 0.4883 - val_accuracy: 0.8937
# Epoch 169/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1063 - accuracy: 0.9593 - val_loss: 0.4347 - val_accuracy: 0.9046
# Epoch 170/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0800 - accuracy: 0.9688 - val_loss: 0.4226 - val_accuracy: 0.8991
# Epoch 171/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0858 - accuracy: 0.9705 - val_loss: 0.4079 - val_accuracy: 0.8999
# Epoch 172/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0701 - accuracy: 0.9735 - val_loss: 0.3938 - val_accuracy: 0.9092
# Epoch 173/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0862 - accuracy: 0.9687 - val_loss: 0.3838 - val_accuracy: 0.9123
# Epoch 174/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0867 - accuracy: 0.9633 - val_loss: 0.4375 - val_accuracy: 0.9030
# Epoch 175/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0731 - accuracy: 0.9702 - val_loss: 0.4036 - val_accuracy: 0.8999
# Epoch 176/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0894 - accuracy: 0.9706 - val_loss: 0.4613 - val_accuracy: 0.8914
# Epoch 177/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0935 - accuracy: 0.9653 - val_loss: 0.4486 - val_accuracy: 0.8953
# Epoch 178/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0740 - accuracy: 0.9743 - val_loss: 0.4049 - val_accuracy: 0.8968
# Epoch 179/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0730 - accuracy: 0.9731 - val_loss: 0.4527 - val_accuracy: 0.8898
# Epoch 180/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0819 - accuracy: 0.9723 - val_loss: 0.5035 - val_accuracy: 0.8898
# Epoch 181/200
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0821 - accuracy: 0.9715 - val_loss: 0.4266 - val_accuracy: 0.8991
# Epoch 182/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0728 - accuracy: 0.9708 - val_loss: 0.3946 - val_accuracy: 0.8984
# Epoch 183/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0864 - accuracy: 0.9708 - val_loss: 0.3764 - val_accuracy: 0.9061
# Epoch 184/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0713 - accuracy: 0.9746 - val_loss: 0.4764 - val_accuracy: 0.8953
# Epoch 185/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0755 - accuracy: 0.9692 - val_loss: 0.3705 - val_accuracy: 0.9131
# Epoch 186/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0667 - accuracy: 0.9727 - val_loss: 0.3514 - val_accuracy: 0.9131
# Epoch 187/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0876 - accuracy: 0.9665 - val_loss: 0.4482 - val_accuracy: 0.9015
# Epoch 188/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0735 - accuracy: 0.9701 - val_loss: 0.3920 - val_accuracy: 0.8991
# Epoch 189/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0830 - accuracy: 0.9659 - val_loss: 0.4609 - val_accuracy: 0.8860
# Epoch 190/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1163 - accuracy: 0.9570 - val_loss: 0.4295 - val_accuracy: 0.8976
# Epoch 191/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.1070 - accuracy: 0.9627 - val_loss: 0.4315 - val_accuracy: 0.8976
# Epoch 192/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0892 - accuracy: 0.9659 - val_loss: 0.3940 - val_accuracy: 0.8999
# Epoch 193/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0926 - accuracy: 0.9705 - val_loss: 0.5309 - val_accuracy: 0.8860
# Epoch 194/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0895 - accuracy: 0.9666 - val_loss: 0.5349 - val_accuracy: 0.8728
# Epoch 195/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0799 - accuracy: 0.9707 - val_loss: 0.4271 - val_accuracy: 0.8976
# Epoch 196/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0698 - accuracy: 0.9737 - val_loss: 0.5032 - val_accuracy: 0.8914
# Epoch 197/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0791 - accuracy: 0.9711 - val_loss: 0.4619 - val_accuracy: 0.9007
# Epoch 198/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0824 - accuracy: 0.9676 - val_loss: 0.4578 - val_accuracy: 0.8976
# Epoch 199/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0717 - accuracy: 0.9730 - val_loss: 0.4621 - val_accuracy: 0.8867
# Epoch 200/200
# 162/162 [==============================] - 2s 11ms/step - loss: 0.0991 - accuracy: 0.9622 - val_loss: 0.3930 - val_accuracy: 0.9139

# %% [markdown]
# #Test accuracy and create confusion matrix

# %%
y_pred = model.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
# Model Accuracy: how often is the classifier correct?
acc=metrics.accuracy_score(y_test, y_pred)
print("Accuracy:",round(acc*100,2))
# Out:
# Accuracy: 91.39

# %%
# Model Precision: what percentage of positive tuples are labeled as such?
p=metrics.precision_score(y_test, y_pred, average='macro')
r=metrics.recall_score(y_test, y_pred,  average='macro')
print("Precision:",round(p*100,2))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",round(r*100,2))
# Out:
# Precision: 91.48
# Recall: 91.39

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[192,   1,  12,   6,   4,   0],
#        [  1, 206,   0,   4,   3,   1],
#        [  4,   4, 191,   7,   6,   3],
#        [  2,   2,   6, 193,   9,   3],
#        [  3,   5,   1,   8, 193,   5],
#        [  0,   1,   0,   9,   1, 203]])

# %%
def quick_plot_con_matrix(y, results,labels):
    # now print confusion metrix
    con = confusion_matrix(y,results)
    a = plt.figure(figsize=(25,15), dpi=50)
    a = sns.heatmap(con, cmap='YlGnBu', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
    a = plt.rcParams.update({'font.size': 20})
    a = plt.title('Confusion Matrix')
    a = plt.xlabel('Predictions')
    a = plt.ylabel('Accpected')

#activity_map = load_activity_map()
labels = [map_ac[x] for x in samples['activity_id']]
quick_plot_con_matrix(y_test,y_pred, labels)
